# %%
import pandas as pd

# %%
df =pd.read_html('https://en.wikipedia.org/wiki/List_of_Xbox_games')[0]

df
# Out:
#                              Title                            Developer(s)  \
#                              Title                            Developer(s)
# 0                  187 Ride or Die                           Ubisoft Paris
# 1              2002 FIFA World Cup     EA CanadaCreationsIntelligent Games
# 2              2006 FIFA World Cup                               EA Canada
# 3                       25 to Life  Avalanche SoftwareRitual Entertainment
# 4                        4x4 Evo 2                        Terminal Reality
# ..                             ...                                     ...
# 983               Yourself!Fitness                            Respondesign
# 984  Yu-Gi-Oh! The Dawn of Destiny     Konami Computer Entertainment Japan
# 985     Zapper: One Wicked Cricket                             Blitz Games
# 986                        Zathura                   High Voltage Software
# ...

# %%
df.to_csv(r'/home/harshvrdhn/Documents/Code/CODE/Jupyter/webscrapingshortcut.csv', index = False)
